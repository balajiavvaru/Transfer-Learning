# %%
# 40X the accuracy is 78 training, 81.5 validation and 80 Test accuracy
# 100X the accuracy is 80 training, 77 validation and 80 Test accuracy

# https://scisharp.github.io/Keras.NET/api/Keras.Applications.DenseNet.DenseNet201.html
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
from tensorflow.keras import layers
import cv2
from PIL import Image
from tensorflow.keras.applications import DenseNet201
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from tqdm import tqdm
from sklearn import metrics
import itertools
import re

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#image_magnification=['40X','100X','200X','400X']

# %%
# # https://stackoverflow.com/questions/273946/how-do-i-resize-an-image-using-pil-and-maintain-its-aspect-ratio
# target=[]
# raw_IMG = []
# def Dataset_loader(DIR, RESIZE, sigmaX=200):
#     IMG = []
#     read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
#     for IMAGE_NAME in tqdm(os.listdir(DIR)):
#         PATH = os.path.join(DIR,IMAGE_NAME)
#         _, ftype = os.path.splitext(PATH)
#         if ftype == ".png":
#             img = read(PATH)
#             raw_IMG.append(np.array(img))
#             img = cv2.resize(img, (RESIZE,RESIZE))
           
#             IMG.append(np.array(img))
            
#             if re.search("malignant", DIR):
#                 target.append(1)
#             else:
#                 target.append(0)
                
#             #print(img.shape)
#     return IMG

# path=os.walk('/Users/balaj/OneDrive/Desktop/Docs/Docs 1/SMU/Capstone A/Code/breast')

# tumor=[]
# for root,directories, files in path:
    
#     for directory in directories:
#         if directory in image_magnification[2]:
#             tumor.append(np.array(Dataset_loader(root+'/'+directory,224)))               
#             #print(root+'/'+directory)

# tumor_final=np.array(list(itertools.chain.from_iterable(tumor)))

# tumor_final.shape

# %%
#loading the saved file once again
tumor_final = np.load(os.path.join('/content/drive/MyDrive/Capstone','features_40.npy'), 
                allow_pickle=True)

#loading the saved file once again
target = np.load(os.path.join('/content/drive/MyDrive/Capstone','target_40.npy'), 
                allow_pickle=True)

# %%
df = pd.DataFrame(target,columns=['target'])
df.head()
# Out:
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.value_counts()
# Out:
# target
# 1         1370
# 0          625
# dtype: int64

# %%
import seaborn as sns
sns.countplot(x = "target", data = df)
plt.title("Distribution of Target Values")
plt.show()

# %%
# Pie chart
df['target'].value_counts().plot.pie(autopct = "%.1f%%")
plt.title("Proportion of Target Value")
plt.show()

# %%
# msk_negative = df['target'] == 0
# msk_positive = df['target'] == 1

# df_positive_undersample = df[msk_positive].sample(n=msk_negative.sum(), random_state=888)
# df_train_undersample = pd.concat([df_positive_undersample, df[msk_negative]])
# df_train_undersample['target'].value_counts()

# %%
# target_under = df_train_undersample['target']

# %%
# df_negative_undersample.index

# %%
# tumor_final_new = tumor_final[df_train_undersample]

# %%
# tumor_final_new

# %%
from sklearn.model_selection import train_test_split

#X_train, X_test, Y_train, Y_test = train_test_split(tumor_final_new/255., target_under, test_size=0.2, random_state=42, shuffle=True)

X_train, X_test, Y_train, Y_test = train_test_split(tumor_final/255., target, test_size=0.2, random_state=42, shuffle=True)

print(pd.DataFrame(Y_test)[0].value_counts())

print(pd.DataFrame(Y_train)[0].value_counts())

# random shuffling the training images and target
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = np.array(Y_train)[s]

# random shuffling the Test images and target
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = np.array(Y_test)[s]

Y_train = to_categorical(Y_train, num_classes= 2)
Y_test = to_categorical(Y_test, num_classes= 2)
# Out:
# 1    265
# 0    134
# Name: 0, dtype: int64
# 1    1105
# 0     491
# Name: 0, dtype: int64

# %%
Y_train = Y_train.astype(int)
counts = np.bincount(Y_train[:, 0])
#weight_for_0 = 1.0 / counts[0]
#weight_for_1 = 1.0 / counts[1]
weight_for_0 = counts[0]/ (counts[0] + counts[1])
weight_for_1 = counts[1]/ (counts[0] + counts[1])
class_weight = {0: weight_for_0, 1: weight_for_1}

# %%
class_weight
# Out:
# {0: 0.6923558897243107, 1: 0.3076441102756892}

# %%
X_train[0].shape
# Out:
# (224, 224, 3)

# %%
#img = X_train[0].reshape[1:]

# %%
#img

# %%
#X_train[0][img].shape

# %%
x_train, x_val, y_train, y_val = train_test_split(
    X_train, Y_train, 
    test_size=0.2, 
    random_state=11,
    shuffle=True
)

w=60
h=40
fig=plt.figure(figsize=(15, 15))
columns = 4
rows = 4

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(Y_train[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(X_train[i], interpolation='nearest')
plt.show()

# %%
from keras.applications.inception_resnet_v2 import InceptionResNetV2 as  PretrainedModel,preprocess_input
from tensorflow.keras.optimizers import SGD

def build_model(backbone, lr=1e-3):
    model = Sequential()
    model.add(backbone)
    # model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Flatten())
    model.add(layers.Dense(4096,activation='swish'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(2048,activation='swish'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(4096,activation='swish'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(2, activation='sigmoid'))
    
    loss_function = tf.keras.losses.SparseCategoricalCrossentropy()
    model.compile(
        loss='binary_crossentropy',
       # optimizer=SGD(lr=0.01, momentum=0.9,nesterov=False),
        optimizer = Adam(lr=lr),
        metrics=['accuracy']
    )
    return model

#resnet = DenseNet201(weights='imagenet',include_top=False,input_shape=(224,224,3))

resnet = tf.keras.applications.inception_v3.InceptionV3(weights = 'imagenet', include_top = False, input_shape = (224,224,3))
#resnet = tf.keras.applications.ResNet50(weights = 'imagenet', include_top = False, input_shape = (224,224,3))

for layer in resnet.layers:
	layer.trainable = False

model = build_model(resnet ,lr = 1e-3)

# %%
for layer in model.layers:
  print(layer.name)
	#layer.trainable = False
# Out:
# inception_v3
# flatten
# dense
# batch_normalization_94
# dropout
# dense_1
# batch_normalization_95
# dropout_1
# dense_2
# batch_normalization_96
# dropout_2
# dense_3

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 4096)              209719296
#
#  batch_normalization_94 (Bat  (None, 4096)             16384
#  chNormalization)
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 2048)              8390656
#
#  batch_normalization_95 (Bat  (None, 2048)             8192
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 4096)              8392704
#
#  batch_normalization_96 (Bat  (None, 4096)             16384
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 4096)              0
#
#  dense_3 (Dense)             (None, 2)                 8194
#
# =================================================================
# Total params: 248,354,594
# Trainable params: 226,531,330
# Non-trainable params: 21,823,264
# _________________________________________________________________

# %%
# Generate batches of tensor image data with real-time data augmentation.

BATCH_SIZE = 16

train_generator = ImageDataGenerator(
        rescale=1./255,
        zoom_range=0.2,  # set range for random zoom
        rotation_range = 90,
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True,  # randomly flip images
        shear_range=0.2
    )

# %%
# https://stackoverflow.com/questions/35074549/how-to-load-a-model-from-an-hdf5-file-in-keras

# https://keras.io/api/callbacks/reduce_lr_on_plateau/

# Reduce learning rate when a metric has stopped improving.
learn_control = ReduceLROnPlateau(monitor='val_loss', patience=5,
                                  verbose=1,factor=0.2, min_lr=1e-7)

safety = EarlyStopping(monitor='val_loss', patience=4, min_delta=2e-4)

# Callback to save the Keras model or model weights at some frequency.
filepath="weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# history = model.fit_generator(
#     train_generator.flow(x_train, y_train, batch_size=BATCH_SIZE),
#     steps_per_epoch=x_train.shape[0] / BATCH_SIZE,
#     epochs=50,
#     validation_data=(x_val, y_val),
#     callbacks=[learn_control, checkpoint],
#     class_weight=class_weight
# )

history = model.fit(
    x_train, y_train, batch_size=BATCH_SIZE,
    steps_per_epoch=x_train.shape[0] / BATCH_SIZE,
    epochs=50,
    validation_data=(x_val, y_val),
    callbacks=[learn_control, checkpoint],
    class_weight=class_weight
)
# Out:
# Epoch 1/50
# 80/79 [==============================] - ETA: 0s - loss: 0.5675 - accuracy: 0.7210WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 17s 93ms/step - loss: 0.5675 - accuracy: 0.7210 - val_loss: 3.3120 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 2/50
# 80/79 [==============================] - ETA: 0s - loss: 0.2184 - accuracy: 0.8260WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 62ms/step - loss: 0.2184 - accuracy: 0.8260 - val_loss: 0.9577 - val_accuracy: 0.7906 - lr: 0.0010
# Epoch 3/50
# 79/79 [============================>.] - ETA: 0s - loss: 0.1258 - accuracy: 0.9003WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 62ms/step - loss: 0.1253 - accuracy: 0.9005 - val_loss: 1.0271 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 4/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0961 - accuracy: 0.9248WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0961 - accuracy: 0.9248 - val_loss: 0.8158 - val_accuracy: 0.8344 - lr: 0.0010
# Epoch 5/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9310WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0753 - accuracy: 0.9310 - val_loss: 0.9884 - val_accuracy: 0.8125 - lr: 0.0010
# Epoch 6/50
# 79/79 [============================>.] - ETA: 0s - loss: 0.0767 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0768 - accuracy: 0.9365 - val_loss: 0.7863 - val_accuracy: 0.8406 - lr: 0.0010
# Epoch 7/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0762 - accuracy: 0.9459WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0762 - accuracy: 0.9459 - val_loss: 1.1644 - val_accuracy: 0.7812 - lr: 0.0010
# Epoch 8/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9436WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0849 - accuracy: 0.9436 - val_loss: 1.2734 - val_accuracy: 0.7844 - lr: 0.0010
# Epoch 9/50
# 79/79 [============================>.] - ETA: 0s - loss: 0.0597 - accuracy: 0.9565WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0614 - accuracy: 0.9553 - val_loss: 0.8583 - val_accuracy: 0.8281 - lr: 0.0010
# Epoch 10/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9600WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0551 - accuracy: 0.9600 - val_loss: 1.1672 - val_accuracy: 0.7969 - lr: 0.0010
# Epoch 11/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0458 - accuracy: 0.9608
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0458 - accuracy: 0.9608 - val_loss: 0.8902 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 12/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0299 - accuracy: 0.9796WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0299 - accuracy: 0.9796 - val_loss: 0.7724 - val_accuracy: 0.8562 - lr: 2.0000e-04
# Epoch 13/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9828WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0255 - accuracy: 0.9828 - val_loss: 0.7178 - val_accuracy: 0.8656 - lr: 2.0000e-04
# Epoch 14/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9906WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0110 - accuracy: 0.9906 - val_loss: 0.7032 - val_accuracy: 0.8562 - lr: 2.0000e-04
# Epoch 15/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9937WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0109 - accuracy: 0.9937 - val_loss: 0.7120 - val_accuracy: 0.8562 - lr: 2.0000e-04
# Epoch 16/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9867WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0154 - accuracy: 0.9867 - val_loss: 0.6901 - val_accuracy: 0.8562 - lr: 2.0000e-04
# Epoch 17/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9914WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0135 - accuracy: 0.9914 - val_loss: 0.6571 - val_accuracy: 0.8500 - lr: 2.0000e-04
# Epoch 18/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9929WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0095 - accuracy: 0.9929 - val_loss: 0.6650 - val_accuracy: 0.8406 - lr: 2.0000e-04
# Epoch 19/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.9914WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 67ms/step - loss: 0.0099 - accuracy: 0.9914 - val_loss: 0.6858 - val_accuracy: 0.8344 - lr: 2.0000e-04
# Epoch 20/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9906WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0147 - accuracy: 0.9906 - val_loss: 0.6739 - val_accuracy: 0.8375 - lr: 2.0000e-04
# Epoch 21/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9969WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0058 - accuracy: 0.9969 - val_loss: 0.6705 - val_accuracy: 0.8562 - lr: 2.0000e-04
# Epoch 22/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9992
# Epoch 22: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0041 - accuracy: 0.9992 - val_loss: 0.6686 - val_accuracy: 0.8625 - lr: 2.0000e-04
# Epoch 23/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9976WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0037 - accuracy: 0.9976 - val_loss: 0.6675 - val_accuracy: 0.8625 - lr: 4.0000e-05
# Epoch 24/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9953WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0058 - accuracy: 0.9953 - val_loss: 0.6813 - val_accuracy: 0.8531 - lr: 4.0000e-05
# Epoch 25/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9976WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0039 - accuracy: 0.9976 - val_loss: 0.6892 - val_accuracy: 0.8531 - lr: 4.0000e-05
# Epoch 26/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9992WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.6863 - val_accuracy: 0.8562 - lr: 4.0000e-05
# Epoch 27/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9906
# Epoch 27: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0113 - accuracy: 0.9906 - val_loss: 0.6701 - val_accuracy: 0.8594 - lr: 4.0000e-05
# Epoch 28/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9875WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0115 - accuracy: 0.9875 - val_loss: 0.6731 - val_accuracy: 0.8625 - lr: 8.0000e-06
# Epoch 29/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9929WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0055 - accuracy: 0.9929 - val_loss: 0.6718 - val_accuracy: 0.8594 - lr: 8.0000e-06
# Epoch 30/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9969WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0040 - accuracy: 0.9969 - val_loss: 0.6698 - val_accuracy: 0.8625 - lr: 8.0000e-06
# Epoch 31/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9961WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0071 - accuracy: 0.9961 - val_loss: 0.6699 - val_accuracy: 0.8594 - lr: 8.0000e-06
# Epoch 32/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.6684 - val_accuracy: 0.8562 - lr: 8.0000e-06
# Epoch 33/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.6681 - val_accuracy: 0.8562 - lr: 1.6000e-06
# Epoch 34/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9992WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.6680 - val_accuracy: 0.8562 - lr: 1.6000e-06
# Epoch 35/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9976WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.6669 - val_accuracy: 0.8594 - lr: 1.6000e-06
# Epoch 36/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9969WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0034 - accuracy: 0.9969 - val_loss: 0.6696 - val_accuracy: 0.8562 - lr: 1.6000e-06
# Epoch 37/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9937
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0109 - accuracy: 0.9937 - val_loss: 0.6723 - val_accuracy: 0.8531 - lr: 1.6000e-06
# Epoch 38/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9992WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.6716 - val_accuracy: 0.8500 - lr: 3.2000e-07
# Epoch 39/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9961WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0038 - accuracy: 0.9961 - val_loss: 0.6674 - val_accuracy: 0.8594 - lr: 3.2000e-07
# Epoch 40/50
# 79/79 [============================>.] - ETA: 0s - loss: 0.0080 - accuracy: 0.9929WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 6s 71ms/step - loss: 0.0079 - accuracy: 0.9929 - val_loss: 0.6711 - val_accuracy: 0.8562 - lr: 3.2000e-07
# Epoch 41/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9945WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0137 - accuracy: 0.9945 - val_loss: 0.6698 - val_accuracy: 0.8562 - lr: 3.2000e-07
# Epoch 42/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9937
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1e-07.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0075 - accuracy: 0.9937 - val_loss: 0.6658 - val_accuracy: 0.8594 - lr: 3.2000e-07
# Epoch 43/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9984WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0029 - accuracy: 0.9984 - val_loss: 0.6677 - val_accuracy: 0.8562 - lr: 1.0000e-07
# Epoch 44/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.6705 - val_accuracy: 0.8562 - lr: 1.0000e-07
# Epoch 45/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9976WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0034 - accuracy: 0.9976 - val_loss: 0.6676 - val_accuracy: 0.8562 - lr: 1.0000e-07
# Epoch 46/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9953WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0067 - accuracy: 0.9953 - val_loss: 0.6695 - val_accuracy: 0.8562 - lr: 1.0000e-07
# Epoch 47/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9961WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0044 - accuracy: 0.9961 - val_loss: 0.6714 - val_accuracy: 0.8562 - lr: 1.0000e-07
# Epoch 48/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9937WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0080 - accuracy: 0.9937 - val_loss: 0.6704 - val_accuracy: 0.8594 - lr: 1.0000e-07
# Epoch 49/50
# 80/79 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9969WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0043 - accuracy: 0.9969 - val_loss: 0.6707 - val_accuracy: 0.8594 - lr: 1.0000e-07
# Epoch 50/50
# 79/79 [============================>.] - ETA: 0s - loss: 0.0106 - accuracy: 0.9921WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0106 - accuracy: 0.9922 - val_loss: 0.6736 - val_accuracy: 0.8562 - lr: 1.0000e-07

# %%
history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()

history_df = pd.DataFrame(history.history)
history_df[['accuracy', 'val_accuracy']].plot()

# %%
X_train.shape
# Out:
# (1596, 224, 224, 3)

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report( np.argmax(Y_test, axis=1), np.argmax(y_pred, axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.80      0.79       134
#            1       0.90      0.89      0.89       265
#
#     accuracy                           0.86       399
#    macro avg       0.84      0.84      0.84       399
# weighted avg       0.86      0.86      0.86       399

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(y_pred, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Breast Cancer')
# Out:
# Confusion matrix, without normalization
# [[107  27]
#  [ 30 235]]

# %%
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
roc_log = roc_auc_score(np.argmax(Y_test, axis=1), np.argmax(y_pred, axis=1))
false_positive_rate, true_positive_rate, threshold = roc_curve(np.argmax(Y_test, axis=1), np.argmax(y_pred, axis=1))
area_under_curve = auc(false_positive_rate, true_positive_rate)

plt.plot([0, 1], [0, 1], 'r--')
plt.plot(false_positive_rate, true_positive_rate, label='AUC = {:.3f}'.format(area_under_curve))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
#plt.savefig(ROC_PLOT_FILE, bbox_inches='tight')
plt.close()

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(np.argmax(Y_test, axis=1), np.argmax(y_pred, axis=1))*100
# Out:
# 85.71428571428571

# %%
#from tensorflow import keras

# %%
#model.save('/Users/balaj/OneDrive/Desktop/Docs/Docs 1/SMU/Capstone A/Code/breast')
